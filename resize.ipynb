# %% [markdown]
# <a href="https://colab.research.google.com/github/Alice049/Arduino/blob/main/resize.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %shell
from google.colab import drive
import pandas as pd

# !unzip '/content/other.zip' -d '/content/other'
# Out:
# Archive:  /content/other.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of /content/other.zip or
#         /content/other.zip.zip, and cannot find /content/other.zip.ZIP, period.

# %%
from PIL import Image
# %matplotlib inline
sample=Image.open('/content/other/other/other_image/30.jpg')
type(sample)
sample
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=960x720 at 0x7F1460914160>

# %%
run=sample.resize(size=(310,260))
run.save('run.png')

# %%
sample.size
# Out:
# (2364, 1773)

# %%
mask=sample.crop((360,50,670,310))
mask.save('mask.png')

# %%
print(sample.format)
print(sample.mode)
# Out:
# JPEG
# RGB

# %%
import matplotlib.pyplot as plt
fig,ax=plt.subplots()
ax.imshow(sample)
plt.show()

# %%
import numpy as np
mask=np.array(mask)
mask.shape
# Out:
# (360, 1080, 4)

# %%
from google.colab import drive
# !unzip '/content/other.zip' -d 'other'
# Out:
# Archive:  /content/other.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of /content/other.zip or
#         /content/other.zip.zip, and cannot find /content/other.zip.ZIP, period.

# %%
from pathlib import Path
p=Path('run')
run=list(p.glob('mask/mask_*.png'))
run[:1]
np.array(sample)[0,0]
